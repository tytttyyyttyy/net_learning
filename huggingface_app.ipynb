# %% [markdown]
# <a href="https://colab.research.google.com/github/tytttyyyttyy/net_learning/blob/main/huggingface_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
# !pip install langchain

# %%
# !pip install langchain_community

# %%
from transformers import pipeline


#img2text
def img2text(url):
        #調用模型
        image_to_text = pipeline("image-to-text", model="Salesforce/blip-image-captioning-large")

        text = image_to_text(url)[0]["generated_text"]


        print(text)
        return text

sentence = img2text("pic2.png")
# Out:
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# a close up of a person riding a bike with a rainbow in the background

# %%
classify = pipeline("sentiment-analysis")
res = classify(sentence)
print(res)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9906343221664429}]

# %%
summarization = pipeline("summarization")
print(summarization(sentence))
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Your max_length is set to 142, but your input_length is only 17. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="mistralai/Mixtral-8x7B-Instruct-v0.1")
print(pipe(sentence))
# Out:
# ...
# model-00003-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00019.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00005-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00006-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00007-of-00019.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00008-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00009-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00010-of-00019.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00011-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00012-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00013-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00014-of-00019.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# ...
